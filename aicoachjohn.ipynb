# %%
import random

def generate_random_number(min_val, max_val):
  return random.randint(min_val, max_val)
min_value = int(input("enter the minimum value : "))
max_value = int(input("enter the maximum value : "))
secretenum = generate_random_number(min_value, max_value)
print(f"Random number between {min_value} and {max_value}")


for i in range(1,8):
    
  
        numin=int(input("predict the number"))
        if numin==secretenum:
            print(f"you have predicted the number {secretenum} successfully in {i} attempt")
            break
        elif numin>secretenum:
            print("secrete number is less than ",numin)
            
        elif numin<secretenum:
            print("secrete number is greater than ",numin )
            

        else:
                print("you entered invalid  number is wrong")
if numin!=secretenum:
    print("your prediction is wrong ")
# Out:
# Random number between 89 and 100
# secrete number is greater than  89
# secrete number is greater than  90
# secrete number is greater than  95
# secrete number is less than  99
# you have predicted the number 98 successfully in 5 attempt
